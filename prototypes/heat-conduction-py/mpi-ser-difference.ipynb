# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dfser = pd.read_csv("1d-ser.txt", header=None).values
dfmpi = pd.read_csv("1d-mpi.txt", header=None).values

# %%
err = dfser-dfmpi

# %%
err
# Out:
# array([[ 0.00000000e+00],
#        [-3.38010962e-05],
#        [-6.76016392e-05],
#        [-1.01401146e-04],
#        [-1.35199068e-04],
#        [-1.68994767e-04],
#        [-2.02787489e-04],
#        [-2.36576338e-04],
#        [-2.70360255e-04],
#        [-3.04137990e-04],
#        [-3.37908084e-04],
#        [-3.71668841e-04],
#        [-4.05418310e-04],
#        [-4.39154267e-04],
#        [-4.72874186e-04],
#        [-5.06575232e-04],
#        [-5.40254235e-04],
#        [-5.73907678e-04],
#        [-6.07531679e-04],
#        [-6.41121979e-04],
#        [-6.74673930e-04],
#        [-7.08182482e-04],
#        [-7.41642173e-04],
#        [-7.75047124e-04],
#        [-8.08391027e-04],
#        [-8.41667142e-04],
#        [-8.74868295e-04],
#        [-9.07986870e-04],
#        [-9.41014813e-04],
#        [-9.73943632e-04],
#        [-1.00676439e-03],
#        [-1.03946773e-03],
#        [-1.07204385e-03],
#        [-1.10448254e-03],
#        [-1.13677315e-03],
# ...

# %%
np.divide(err, dfser, errper)
# Out:
# /var/folders/zy/jlkwbd2s5h9_hfdtrd0zn11r0000gn/T/ipykernel_44777/326163764.py:1: RuntimeWarning: invalid value encountered in true_divide
#   np.divide(err, dfser, errper)
# array([[        nan],
#        [-0.00498495],
#        [-0.00498673],
#        [-0.00498945],
#        [-0.00499312],
#        [-0.00499774],
#        [-0.0050033 ],
#        [-0.00500982],
#        [-0.00501728],
#        [-0.00502569],
#        [-0.00503506],
#        [-0.00504537],
#        [-0.00505664],
#        [-0.00506887],
#        [-0.00508205],
#        [-0.00509619],
#        [-0.00511129],
#        [-0.00512735],
#        [-0.00514438],
#        [-0.00516238],
#        [-0.00518136],
#        [-0.00520131],
#        [-0.00522224],
#        [-0.00524416],
#        [-0.00526707],
#        [-0.00529098],
#        [-0.00531588],
#        [-0.0053418 ],
#        [-0.00536873],
#        [-0.00539669],
#        [-0.00542568],
#        [-0.00545571],
#        [-0.0054868 ],
#        [-0.00551894],
# ...
